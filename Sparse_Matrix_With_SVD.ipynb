# %%
import pandas
import numpy as np

# %%
columns = ["review_text", "score"]

training = pandas.read_csv('input/training.txt', delimiter = "\t", header=None)
training.columns = columns

# %% [markdown]
# ## Text Pre-processing
# __[Text Preprocessing in Python: Steps, Tools, and Examples](https://medium.com/@datamonsters/text-preprocessing-in-python-steps-tools-and-examples-bf025f872908)__

# %%
import string
from sklearn.feature_extraction import text

import nltk
nltk.download('punkt')
nltk.download('wordnet')

from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/mhssain9/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mhssain9/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def process_dataframe(dataframe, input_column, output_column):
    for input, output in zip(input_column,output_column):
        dataframe[output] = dataframe[input].astype(str).str.lower()

        dataframe[output] = dataframe[output].str.replace('\d+', '')

        dataframe[output] = dataframe[output].str.replace('[{}]'.format(string.punctuation), '')

        stop_words = text.ENGLISH_STOP_WORDS
        dataframe[output] = dataframe[output].str.replace( '\b(?:{})\b'.format('|'.join(stop_words)), '')
        dataframe[output] = dataframe[output].str.replace(r'\s+', ' ')

        stemmer= SnowballStemmer("english")
        lemmatizer=WordNetLemmatizer()

        dataframe[output] = dataframe[output].apply(word_tokenize)
        dataframe[output] = dataframe[output].apply(lambda x: [stemmer.stem(y) for y in x])
        dataframe[output] = dataframe[output].apply(lambda x: [lemmatizer.lemmatize(y) for y in x])
        dataframe[output] = dataframe[output].apply(lambda x: " ".join(x) )
    
    return dataframe

# %%
training = process_dataframe(training, ["review_text"], ["word_token"])

# %% [markdown]
# ## Bag of Words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# ### Vectorization with SVD

# %%
def vectorize_words(dataframe, x, keys=None):
    
    vectorizer = TfidfVectorizer(vocabulary = keys)
    # tokenize and build vocab
    vectorizer.fit(dataframe[x])
    # encode document
    vectorized_word_token = vectorizer.transform(dataframe[x])
    
    return vectorized_word_token

# %%
def svd_words(vectorized_word_token, pca_n_components=1000, random_state=None):
    
    svd = TruncatedSVD(n_components=pca_n_components, random_state=random_state)
    vectorized_word_token = svd.fit_transform(vectorized_word_token) 
    
    return svd, vectorized_word_token

# %%
x_naive = vectorize_words(training, "word_token")
_, x = svd_words(x_naive)

# %%
y = training["score"]
y = np.ravel(y)

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Cross-validation

# %%
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import recall_score

# %%
def cross_validation(classifier_dic, X, y):
    scoring = ['precision_weighted', 'recall_weighted', 'f1_weighted']
    
    scores = {}
    for key, classifier in classifier_dic.items():
        scores[key] = cross_validate(classifier, X, y, cv=3, return_train_score=True, scoring=scoring)
        print (key, " scores: ", scores[key], "\n" )
        
    return scores

# %% [markdown]
# ### Classifier

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.model_selection import GridSearchCV
import itertools

# %%
classifier_dic = {}
classifier_dic['MLPClassifier'] = MLPClassifier(max_iter=500, early_stopping=True) 
classifier_dic['LogisticRegression'] = LogisticRegression(solver='liblinear', multi_class='auto')
classifier_dic['AdaBoostClassifier'] = AdaBoostClassifier()
# SVC is very slow running 
classifier_dic['SVC'] = SVC(gamma='auto')

# %% [markdown]
# #### Grid Search to find parameters to to achieve best possible results

# %%
params = {}

units = []
for hidden_layers in range(1, 4):
    units = units + [x for x in itertools.product(np.arange(32, 257, 32),repeat=hidden_layers)]

params['MLPClassifier'] = dict(hidden_layer_sizes=units)
params['SVC'] = dict( kernel=['linear', 'poly', 'rbf', 'sigmoid'], C=np.arange(0.1, 2.0, 0.3) )
params['AdaBoostClassifier'] = dict( n_estimators=np.arange(20, 101, 10) )
params['LogisticRegression'] = dict( penalty=['l1', 'l2'], C=np.arange(0.1, 2.0, 0.3) )

# %%
grid = {}
grid_result = {}
for key, classifier in classifier_dic.items():
        if key in params:
            grid[key] = GridSearchCV(classifier, param_grid=params[key], cv=3, verbose=2)
            grid_result[key] = grid[key].fit(x, y)

            # summarize results
            print(key, " : Best: %f using %s" % (grid_result[key].best_score_, grid_result[key].best_params_))
# Out:
# Fitting 3 folds for each of 584 candidates, totalling 1752 fits
# [CV] hidden_layer_sizes=(32,) ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ......................... hidden_layer_sizes=(32,), total=  18.9s
# [CV] hidden_layer_sizes=(32,) ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   18.9s remaining:    0.0s
# [CV] ......................... hidden_layer_sizes=(32,), total=  17.8s
# [CV] hidden_layer_sizes=(32,) ........................................
# [CV] ......................... hidden_layer_sizes=(32,), total=  24.5s
# [CV] hidden_layer_sizes=(64,) ........................................
# [CV] ......................... hidden_layer_sizes=(64,), total=  18.1s
# [CV] hidden_layer_sizes=(64,) ........................................
# [CV] ......................... hidden_layer_sizes=(64,), total=  14.3s
# [CV] hidden_layer_sizes=(64,) ........................................
# [CV] ......................... hidden_layer_sizes=(64,), total=  15.3s
# [CV] hidden_layer_sizes=(96,) ........................................
# [CV] ......................... hidden_layer_sizes=(96,), total=  19.4s
# [CV] hidden_layer_sizes=(96,) ........................................
# [CV] ......................... hidden_layer_sizes=(96,), total=  20.5s
# [CV] hidden_layer_sizes=(96,) ........................................
# [CV] ......................... hidden_layer_sizes=(96,), total=  21.0s
# [CV] hidden_layer_sizes=(128,) .......................................
# [CV] ........................ hidden_layer_sizes=(128,), total=  29.6s
# [CV] hidden_layer_sizes=(128,) .......................................
# [CV] ........................ hidden_layer_sizes=(128,), total=  37.4s
# [CV] hidden_layer_sizes=(128,) .......................................
# [CV] ........................ hidden_layer_sizes=(128,), total=  25.4s
# [CV] hidden_layer_sizes=(160,) .......................................
# [CV] ........................ hidden_layer_sizes=(160,), total=  37.0s
# [CV] hidden_layer_sizes=(160,) .......................................
# [CV] ........................ hidden_layer_sizes=(160,), total=  41.0s
# [CV] hidden_layer_sizes=(160,) .......................................
# [CV] ........................ hidden_layer_sizes=(160,), total=  27.1s
# [CV] hidden_layer_sizes=(192,) .......................................
# [CV] ........................ hidden_layer_sizes=(192,), total=  33.7s
# [CV] hidden_layer_sizes=(192,) .......................................
# [CV] ........................ hidden_layer_sizes=(192,), total=  37.7s
# [CV] hidden_layer_sizes=(192,) .......................................
# [CV] ........................ hidden_layer_sizes=(192,), total=  41.6s
# [CV] hidden_layer_sizes=(224,) .......................................
# [CV] ........................ hidden_layer_sizes=(224,), total=  48.7s
# [CV] hidden_layer_sizes=(224,) .......................................
# [CV] ........................ hidden_layer_sizes=(224,), total=  59.5s
# [CV] hidden_layer_sizes=(224,) .......................................
# [CV] ........................ hidden_layer_sizes=(224,), total=  41.2s
# [CV] hidden_layer_sizes=(256,) .......................................
# [CV] ........................ hidden_layer_sizes=(256,), total=  55.6s
# [CV] hidden_layer_sizes=(256,) .......................................
# [CV] ........................ hidden_layer_sizes=(256,), total= 1.0min
# [CV] hidden_layer_sizes=(256,) .......................................
# [CV] ........................ hidden_layer_sizes=(256,), total=  44.5s
# [CV] hidden_layer_sizes=(32, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 32), total=  33.0s
# [CV] hidden_layer_sizes=(32, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 32), total=  32.3s
# [CV] hidden_layer_sizes=(32, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 32), total=  29.7s
# [CV] hidden_layer_sizes=(32, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 64), total=  20.6s
# [CV] hidden_layer_sizes=(32, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 64), total=  30.1s
# [CV] hidden_layer_sizes=(32, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 64), total=  29.4s
# [CV] hidden_layer_sizes=(32, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 96), total=  26.5s
# [CV] hidden_layer_sizes=(32, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 96), total=  37.3s
# [CV] hidden_layer_sizes=(32, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(32, 96), total=  24.0s
# [CV] hidden_layer_sizes=(32, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 128), total=  29.1s
# [CV] hidden_layer_sizes=(32, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 128), total=  31.6s
# [CV] hidden_layer_sizes=(32, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 128), total=  34.4s
# [CV] hidden_layer_sizes=(32, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 160), total=  40.1s
# [CV] hidden_layer_sizes=(32, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 160), total=  47.8s
# [CV] hidden_layer_sizes=(32, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 160), total=  43.8s
# [CV] hidden_layer_sizes=(32, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 192), total=  27.8s
# [CV] hidden_layer_sizes=(32, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 192), total=  36.4s
# [CV] hidden_layer_sizes=(32, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 192), total=  33.0s
# [CV] hidden_layer_sizes=(32, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 224), total=  27.8s
# [CV] hidden_layer_sizes=(32, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 224), total=  44.5s
# [CV] hidden_layer_sizes=(32, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 224), total=  39.3s
# [CV] hidden_layer_sizes=(32, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 256), total=  38.6s
# [CV] hidden_layer_sizes=(32, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 256), total=  29.6s
# [CV] hidden_layer_sizes=(32, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(32, 256), total=  30.6s
# [CV] hidden_layer_sizes=(64, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 32), total=  25.0s
# [CV] hidden_layer_sizes=(64, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 32), total=  29.6s
# [CV] hidden_layer_sizes=(64, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 32), total=  25.4s
# [CV] hidden_layer_sizes=(64, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 64), total=  29.7s
# [CV] hidden_layer_sizes=(64, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 64), total=  25.6s
# [CV] hidden_layer_sizes=(64, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 64), total=  23.6s
# [CV] hidden_layer_sizes=(64, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 96), total=  29.2s
# [CV] hidden_layer_sizes=(64, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 96), total=  18.8s
# [CV] hidden_layer_sizes=(64, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(64, 96), total=  20.8s
# [CV] hidden_layer_sizes=(64, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 128), total=  31.1s
# [CV] hidden_layer_sizes=(64, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 128), total=  22.7s
# [CV] hidden_layer_sizes=(64, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 128), total=  20.4s
# [CV] hidden_layer_sizes=(64, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 160), total=  38.5s
# [CV] hidden_layer_sizes=(64, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 160), total=  35.8s
# [CV] hidden_layer_sizes=(64, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 160), total=  38.2s
# [CV] hidden_layer_sizes=(64, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 192), total=  31.6s
# [CV] hidden_layer_sizes=(64, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 192), total=  45.7s
# [CV] hidden_layer_sizes=(64, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 192), total=  34.0s
# [CV] hidden_layer_sizes=(64, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 224), total=  27.4s
# [CV] hidden_layer_sizes=(64, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 224), total=  34.6s
# [CV] hidden_layer_sizes=(64, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 224), total=  38.7s
# [CV] hidden_layer_sizes=(64, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 256), total=  38.0s
# [CV] hidden_layer_sizes=(64, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 256), total=  35.6s
# [CV] hidden_layer_sizes=(64, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(64, 256), total=  33.1s
# [CV] hidden_layer_sizes=(96, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 32), total=  38.4s
# [CV] hidden_layer_sizes=(96, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 32), total=  32.4s
# [CV] hidden_layer_sizes=(96, 32) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 32), total=  28.1s
# [CV] hidden_layer_sizes=(96, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 64), total=  24.7s
# [CV] hidden_layer_sizes=(96, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 64), total=  28.2s
# [CV] hidden_layer_sizes=(96, 64) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 64), total=  37.8s
# [CV] hidden_layer_sizes=(96, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 96), total=  29.1s
# [CV] hidden_layer_sizes=(96, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 96), total=  30.6s
# [CV] hidden_layer_sizes=(96, 96) .....................................
# [CV] ...................... hidden_layer_sizes=(96, 96), total=  28.5s
# [CV] hidden_layer_sizes=(96, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 128), total=  24.9s
# [CV] hidden_layer_sizes=(96, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 128), total=  24.2s
# [CV] hidden_layer_sizes=(96, 128) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 128), total=  30.0s
# [CV] hidden_layer_sizes=(96, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 160), total=  41.8s
# [CV] hidden_layer_sizes=(96, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 160), total=  34.8s
# [CV] hidden_layer_sizes=(96, 160) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 160), total=  31.9s
# [CV] hidden_layer_sizes=(96, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 192), total=  39.7s
# [CV] hidden_layer_sizes=(96, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 192), total=  29.6s
# [CV] hidden_layer_sizes=(96, 192) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 192), total=  37.1s
# [CV] hidden_layer_sizes=(96, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 224), total=  36.2s
# [CV] hidden_layer_sizes=(96, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 224), total=  35.1s
# [CV] hidden_layer_sizes=(96, 224) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 224), total=  34.7s
# [CV] hidden_layer_sizes=(96, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 256), total=  32.8s
# [CV] hidden_layer_sizes=(96, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 256), total=  33.8s
# [CV] hidden_layer_sizes=(96, 256) ....................................
# [CV] ..................... hidden_layer_sizes=(96, 256), total=  37.0s
# [CV] hidden_layer_sizes=(128, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 32), total=  40.2s
# [CV] hidden_layer_sizes=(128, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 32), total=  32.0s
# [CV] hidden_layer_sizes=(128, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 32), total=  34.2s
# [CV] hidden_layer_sizes=(128, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 64), total=  26.8s
# [CV] hidden_layer_sizes=(128, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 64), total=  32.8s
# [CV] hidden_layer_sizes=(128, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 64), total=  27.7s
# [CV] hidden_layer_sizes=(128, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 96), total=  36.4s
# [CV] hidden_layer_sizes=(128, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 96), total=  32.7s
# [CV] hidden_layer_sizes=(128, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(128, 96), total=  45.5s
# [CV] hidden_layer_sizes=(128, 128) ...................................
# [CV] .................... hidden_layer_sizes=(128, 128), total=  29.1s
# [CV] hidden_layer_sizes=(128, 128) ...................................
# [CV] .................... hidden_layer_sizes=(128, 128), total=  35.8s
# [CV] hidden_layer_sizes=(128, 128) ...................................
# [CV] .................... hidden_layer_sizes=(128, 128), total=  32.0s
# [CV] hidden_layer_sizes=(128, 160) ...................................
# [CV] .................... hidden_layer_sizes=(128, 160), total=  33.7s
# [CV] hidden_layer_sizes=(128, 160) ...................................
# [CV] .................... hidden_layer_sizes=(128, 160), total=  31.2s
# [CV] hidden_layer_sizes=(128, 160) ...................................
# [CV] .................... hidden_layer_sizes=(128, 160), total=  34.3s
# [CV] hidden_layer_sizes=(128, 192) ...................................
# [CV] .................... hidden_layer_sizes=(128, 192), total=  46.1s
# [CV] hidden_layer_sizes=(128, 192) ...................................
# [CV] .................... hidden_layer_sizes=(128, 192), total=  44.5s
# [CV] hidden_layer_sizes=(128, 192) ...................................
# [CV] .................... hidden_layer_sizes=(128, 192), total=  37.8s
# [CV] hidden_layer_sizes=(128, 224) ...................................
# [CV] .................... hidden_layer_sizes=(128, 224), total=  40.3s
# [CV] hidden_layer_sizes=(128, 224) ...................................
# [CV] .................... hidden_layer_sizes=(128, 224), total=  47.1s
# [CV] hidden_layer_sizes=(128, 224) ...................................
# [CV] .................... hidden_layer_sizes=(128, 224), total=  44.4s
# [CV] hidden_layer_sizes=(128, 256) ...................................
# [CV] .................... hidden_layer_sizes=(128, 256), total=  42.2s
# [CV] hidden_layer_sizes=(128, 256) ...................................
# [CV] .................... hidden_layer_sizes=(128, 256), total=  46.4s
# [CV] hidden_layer_sizes=(128, 256) ...................................
# [CV] .................... hidden_layer_sizes=(128, 256), total=  45.3s
# [CV] hidden_layer_sizes=(160, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 32), total=  40.6s
# [CV] hidden_layer_sizes=(160, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 32), total=  34.2s
# [CV] hidden_layer_sizes=(160, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 32), total=  35.9s
# [CV] hidden_layer_sizes=(160, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 64), total=  35.7s
# [CV] hidden_layer_sizes=(160, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 64), total=  41.3s
# [CV] hidden_layer_sizes=(160, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 64), total=  33.9s
# [CV] hidden_layer_sizes=(160, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 96), total=  36.4s
# [CV] hidden_layer_sizes=(160, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 96), total=  37.8s
# [CV] hidden_layer_sizes=(160, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(160, 96), total=  37.1s
# [CV] hidden_layer_sizes=(160, 128) ...................................
# [CV] .................... hidden_layer_sizes=(160, 128), total=  44.7s
# [CV] hidden_layer_sizes=(160, 128) ...................................
# [CV] .................... hidden_layer_sizes=(160, 128), total=  41.6s
# [CV] hidden_layer_sizes=(160, 128) ...................................
# [CV] .................... hidden_layer_sizes=(160, 128), total=  37.8s
# [CV] hidden_layer_sizes=(160, 160) ...................................
# [CV] .................... hidden_layer_sizes=(160, 160), total=  35.8s
# [CV] hidden_layer_sizes=(160, 160) ...................................
# [CV] .................... hidden_layer_sizes=(160, 160), total=  42.3s
# [CV] hidden_layer_sizes=(160, 160) ...................................
# [CV] .................... hidden_layer_sizes=(160, 160), total=  44.8s
# [CV] hidden_layer_sizes=(160, 192) ...................................
# [CV] .................... hidden_layer_sizes=(160, 192), total=  56.1s
# [CV] hidden_layer_sizes=(160, 192) ...................................
# [CV] .................... hidden_layer_sizes=(160, 192), total=  46.7s
# [CV] hidden_layer_sizes=(160, 192) ...................................
# [CV] .................... hidden_layer_sizes=(160, 192), total=  43.9s
# [CV] hidden_layer_sizes=(160, 224) ...................................
# [CV] .................... hidden_layer_sizes=(160, 224), total=  40.3s
# [CV] hidden_layer_sizes=(160, 224) ...................................
# [CV] .................... hidden_layer_sizes=(160, 224), total=  51.6s
# [CV] hidden_layer_sizes=(160, 224) ...................................
# [CV] .................... hidden_layer_sizes=(160, 224), total=  55.2s
# [CV] hidden_layer_sizes=(160, 256) ...................................
# [CV] .................... hidden_layer_sizes=(160, 256), total=  44.6s
# [CV] hidden_layer_sizes=(160, 256) ...................................
# [CV] .................... hidden_layer_sizes=(160, 256), total=  50.2s
# [CV] hidden_layer_sizes=(160, 256) ...................................
# [CV] .................... hidden_layer_sizes=(160, 256), total=  43.0s
# [CV] hidden_layer_sizes=(192, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 32), total=  49.7s
# [CV] hidden_layer_sizes=(192, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 32), total=  39.3s
# [CV] hidden_layer_sizes=(192, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 32), total=  40.6s
# [CV] hidden_layer_sizes=(192, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 64), total=  36.4s
# [CV] hidden_layer_sizes=(192, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 64), total=  34.3s
# [CV] hidden_layer_sizes=(192, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 64), total=  25.4s
# [CV] hidden_layer_sizes=(192, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 96), total=  37.7s
# [CV] hidden_layer_sizes=(192, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 96), total=  48.7s
# [CV] hidden_layer_sizes=(192, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(192, 96), total=  39.6s
# [CV] hidden_layer_sizes=(192, 128) ...................................
# [CV] .................... hidden_layer_sizes=(192, 128), total=  44.9s
# [CV] hidden_layer_sizes=(192, 128) ...................................
# [CV] .................... hidden_layer_sizes=(192, 128), total=  50.0s
# [CV] hidden_layer_sizes=(192, 128) ...................................
# [CV] .................... hidden_layer_sizes=(192, 128), total=  39.9s
# [CV] hidden_layer_sizes=(192, 160) ...................................
# [CV] .................... hidden_layer_sizes=(192, 160), total=  54.1s
# [CV] hidden_layer_sizes=(192, 160) ...................................
# [CV] .................... hidden_layer_sizes=(192, 160), total=  45.3s
# [CV] hidden_layer_sizes=(192, 160) ...................................
# [CV] .................... hidden_layer_sizes=(192, 160), total=  50.0s
# [CV] hidden_layer_sizes=(192, 192) ...................................
# [CV] .................... hidden_layer_sizes=(192, 192), total=  57.3s
# [CV] hidden_layer_sizes=(192, 192) ...................................
# [CV] .................... hidden_layer_sizes=(192, 192), total=  59.1s
# [CV] hidden_layer_sizes=(192, 192) ...................................
# [CV] .................... hidden_layer_sizes=(192, 192), total=  53.2s
# [CV] hidden_layer_sizes=(192, 224) ...................................
# [CV] .................... hidden_layer_sizes=(192, 224), total=  56.0s
# [CV] hidden_layer_sizes=(192, 224) ...................................
# [CV] .................... hidden_layer_sizes=(192, 224), total=  53.7s
# [CV] hidden_layer_sizes=(192, 224) ...................................
# [CV] .................... hidden_layer_sizes=(192, 224), total=  54.5s
# [CV] hidden_layer_sizes=(192, 256) ...................................
# [CV] .................... hidden_layer_sizes=(192, 256), total=  50.1s
# [CV] hidden_layer_sizes=(192, 256) ...................................
# [CV] .................... hidden_layer_sizes=(192, 256), total=  51.3s
# [CV] hidden_layer_sizes=(192, 256) ...................................
# [CV] .................... hidden_layer_sizes=(192, 256), total=  56.7s
# [CV] hidden_layer_sizes=(224, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 32), total=  50.1s
# [CV] hidden_layer_sizes=(224, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 32), total=  32.9s
# [CV] hidden_layer_sizes=(224, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 32), total= 1.0min
# [CV] hidden_layer_sizes=(224, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 64), total=  49.0s
# [CV] hidden_layer_sizes=(224, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 64), total=  43.6s
# [CV] hidden_layer_sizes=(224, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 64), total=  49.3s
# [CV] hidden_layer_sizes=(224, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 96), total=  52.6s
# [CV] hidden_layer_sizes=(224, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 96), total=  42.6s
# [CV] hidden_layer_sizes=(224, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(224, 96), total=  39.2s
# [CV] hidden_layer_sizes=(224, 128) ...................................
# [CV] .................... hidden_layer_sizes=(224, 128), total=  44.8s
# [CV] hidden_layer_sizes=(224, 128) ...................................
# [CV] .................... hidden_layer_sizes=(224, 128), total=  33.8s
# [CV] hidden_layer_sizes=(224, 128) ...................................
# [CV] .................... hidden_layer_sizes=(224, 128), total=  46.6s
# [CV] hidden_layer_sizes=(224, 160) ...................................
# [CV] .................... hidden_layer_sizes=(224, 160), total=  53.9s
# [CV] hidden_layer_sizes=(224, 160) ...................................
# [CV] .................... hidden_layer_sizes=(224, 160), total=  58.9s
# [CV] hidden_layer_sizes=(224, 160) ...................................
# [CV] .................... hidden_layer_sizes=(224, 160), total=  52.1s
# [CV] hidden_layer_sizes=(224, 192) ...................................
# [CV] .................... hidden_layer_sizes=(224, 192), total= 1.1min
# [CV] hidden_layer_sizes=(224, 192) ...................................
# [CV] .................... hidden_layer_sizes=(224, 192), total=  45.3s
# [CV] hidden_layer_sizes=(224, 192) ...................................
# [CV] .................... hidden_layer_sizes=(224, 192), total=  43.6s
# [CV] hidden_layer_sizes=(224, 224) ...................................
# [CV] .................... hidden_layer_sizes=(224, 224), total= 1.0min
# [CV] hidden_layer_sizes=(224, 224) ...................................
# [CV] .................... hidden_layer_sizes=(224, 224), total= 1.1min
# [CV] hidden_layer_sizes=(224, 224) ...................................
# [CV] .................... hidden_layer_sizes=(224, 224), total=  55.0s
# [CV] hidden_layer_sizes=(224, 256) ...................................
# [CV] .................... hidden_layer_sizes=(224, 256), total=  49.3s
# [CV] hidden_layer_sizes=(224, 256) ...................................
# [CV] .................... hidden_layer_sizes=(224, 256), total=  55.8s
# [CV] hidden_layer_sizes=(224, 256) ...................................
# [CV] .................... hidden_layer_sizes=(224, 256), total=  52.9s
# [CV] hidden_layer_sizes=(256, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 32), total=  59.4s
# [CV] hidden_layer_sizes=(256, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 32), total=  42.8s
# [CV] hidden_layer_sizes=(256, 32) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 32), total=  58.6s
# [CV] hidden_layer_sizes=(256, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 64), total=  38.3s
# [CV] hidden_layer_sizes=(256, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 64), total=  42.9s
# [CV] hidden_layer_sizes=(256, 64) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 64), total=  47.7s
# [CV] hidden_layer_sizes=(256, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 96), total=  48.4s
# [CV] hidden_layer_sizes=(256, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 96), total=  52.7s
# [CV] hidden_layer_sizes=(256, 96) ....................................
# [CV] ..................... hidden_layer_sizes=(256, 96), total=  55.1s
# [CV] hidden_layer_sizes=(256, 128) ...................................
# [CV] .................... hidden_layer_sizes=(256, 128), total=  51.3s
# [CV] hidden_layer_sizes=(256, 128) ...................................
# [CV] .................... hidden_layer_sizes=(256, 128), total=  52.8s
# [CV] hidden_layer_sizes=(256, 128) ...................................
# [CV] .................... hidden_layer_sizes=(256, 128), total=  43.9s
# [CV] hidden_layer_sizes=(256, 160) ...................................
# [CV] .................... hidden_layer_sizes=(256, 160), total= 1.1min
# [CV] hidden_layer_sizes=(256, 160) ...................................
# [CV] .................... hidden_layer_sizes=(256, 160), total= 1.1min
# [CV] hidden_layer_sizes=(256, 160) ...................................
# [CV] .................... hidden_layer_sizes=(256, 160), total=  59.0s
# [CV] hidden_layer_sizes=(256, 192) ...................................
# [CV] .................... hidden_layer_sizes=(256, 192), total= 1.0min
# [CV] hidden_layer_sizes=(256, 192) ...................................
# [CV] .................... hidden_layer_sizes=(256, 192), total= 1.1min
# [CV] hidden_layer_sizes=(256, 192) ...................................
# [CV] .................... hidden_layer_sizes=(256, 192), total=  55.7s
# [CV] hidden_layer_sizes=(256, 224) ...................................
# [CV] .................... hidden_layer_sizes=(256, 224), total=  51.5s
# [CV] hidden_layer_sizes=(256, 224) ...................................
# [CV] .................... hidden_layer_sizes=(256, 224), total= 1.2min
# [CV] hidden_layer_sizes=(256, 224) ...................................
# [CV] .................... hidden_layer_sizes=(256, 224), total= 1.1min
# [CV] hidden_layer_sizes=(256, 256) ...................................
# [CV] .................... hidden_layer_sizes=(256, 256), total=  56.4s
# [CV] hidden_layer_sizes=(256, 256) ...................................
# [CV] .................... hidden_layer_sizes=(256, 256), total=  59.4s
# [CV] hidden_layer_sizes=(256, 256) ...................................
# [CV] .................... hidden_layer_sizes=(256, 256), total=  57.8s
# [CV] hidden_layer_sizes=(32, 32, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 32), total=  37.2s
# [CV] hidden_layer_sizes=(32, 32, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 32), total=  47.9s
# [CV] hidden_layer_sizes=(32, 32, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 32), total=  36.8s
# [CV] hidden_layer_sizes=(32, 32, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 64), total=  52.0s
# [CV] hidden_layer_sizes=(32, 32, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 64), total=  42.9s
# [CV] hidden_layer_sizes=(32, 32, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 64), total=  41.8s
# [CV] hidden_layer_sizes=(32, 32, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 96), total=  28.1s
# [CV] hidden_layer_sizes=(32, 32, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 96), total=  28.5s
# [CV] hidden_layer_sizes=(32, 32, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 32, 96), total=  21.5s
# [CV] hidden_layer_sizes=(32, 32, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 128), total=  27.6s
# [CV] hidden_layer_sizes=(32, 32, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 128), total=  36.4s
# [CV] hidden_layer_sizes=(32, 32, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 128), total=  23.9s
# [CV] hidden_layer_sizes=(32, 32, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 160), total=  31.1s
# [CV] hidden_layer_sizes=(32, 32, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 160), total=  41.0s
# [CV] hidden_layer_sizes=(32, 32, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 160), total=  43.9s
# [CV] hidden_layer_sizes=(32, 32, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 192), total=  39.6s
# [CV] hidden_layer_sizes=(32, 32, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 192), total=  48.6s
# [CV] hidden_layer_sizes=(32, 32, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 192), total=  41.6s
# [CV] hidden_layer_sizes=(32, 32, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 224), total=  35.9s
# [CV] hidden_layer_sizes=(32, 32, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 224), total=  48.4s
# [CV] hidden_layer_sizes=(32, 32, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 224), total=  46.7s
# [CV] hidden_layer_sizes=(32, 32, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 256), total=  33.4s
# [CV] hidden_layer_sizes=(32, 32, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 256), total= 1.3min
# [CV] hidden_layer_sizes=(32, 32, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 32, 256), total=  41.4s
# [CV] hidden_layer_sizes=(32, 64, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 32), total=  45.7s
# [CV] hidden_layer_sizes=(32, 64, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 32), total=  38.6s
# [CV] hidden_layer_sizes=(32, 64, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 32), total=  28.6s
# [CV] hidden_layer_sizes=(32, 64, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 64), total=  35.6s
# [CV] hidden_layer_sizes=(32, 64, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 64), total=  28.7s
# [CV] hidden_layer_sizes=(32, 64, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 64), total=  36.7s
# [CV] hidden_layer_sizes=(32, 64, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 96), total=  38.4s
# [CV] hidden_layer_sizes=(32, 64, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 96), total=  35.6s
# [CV] hidden_layer_sizes=(32, 64, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 64, 96), total=  38.8s
# [CV] hidden_layer_sizes=(32, 64, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 128), total=  40.2s
# [CV] hidden_layer_sizes=(32, 64, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 128), total=  32.2s
# [CV] hidden_layer_sizes=(32, 64, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 128), total=  35.0s
# [CV] hidden_layer_sizes=(32, 64, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 160), total=  48.9s
# [CV] hidden_layer_sizes=(32, 64, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 160), total= 1.1min
# [CV] hidden_layer_sizes=(32, 64, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 160), total=  46.4s
# [CV] hidden_layer_sizes=(32, 64, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 192), total=  38.4s
# [CV] hidden_layer_sizes=(32, 64, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 192), total= 1.1min
# [CV] hidden_layer_sizes=(32, 64, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 192), total=  38.6s
# [CV] hidden_layer_sizes=(32, 64, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 224), total=  36.1s
# [CV] hidden_layer_sizes=(32, 64, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 224), total=  30.4s
# [CV] hidden_layer_sizes=(32, 64, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 224), total=  47.1s
# [CV] hidden_layer_sizes=(32, 64, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 256), total=  49.9s
# [CV] hidden_layer_sizes=(32, 64, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 256), total=  58.3s
# [CV] hidden_layer_sizes=(32, 64, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 64, 256), total= 1.0min
# [CV] hidden_layer_sizes=(32, 96, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 32), total=  36.1s
# [CV] hidden_layer_sizes=(32, 96, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 32), total=  37.3s
# [CV] hidden_layer_sizes=(32, 96, 32) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 32), total=  30.8s
# [CV] hidden_layer_sizes=(32, 96, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 64), total=  35.5s
# [CV] hidden_layer_sizes=(32, 96, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 64), total=  32.9s
# [CV] hidden_layer_sizes=(32, 96, 64) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 64), total=  38.9s
# [CV] hidden_layer_sizes=(32, 96, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 96), total=  30.0s
# [CV] hidden_layer_sizes=(32, 96, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 96), total=  35.8s
# [CV] hidden_layer_sizes=(32, 96, 96) .................................
# [CV] .................. hidden_layer_sizes=(32, 96, 96), total=  45.7s
# [CV] hidden_layer_sizes=(32, 96, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 128), total=  39.3s
# [CV] hidden_layer_sizes=(32, 96, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 128), total= 1.1min
# [CV] hidden_layer_sizes=(32, 96, 128) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 128), total=  40.6s
# [CV] hidden_layer_sizes=(32, 96, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 160), total=  33.1s
# [CV] hidden_layer_sizes=(32, 96, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 160), total= 1.1min
# [CV] hidden_layer_sizes=(32, 96, 160) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 160), total=  37.6s
# [CV] hidden_layer_sizes=(32, 96, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 192), total=  46.7s
# [CV] hidden_layer_sizes=(32, 96, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 192), total=  59.2s
# [CV] hidden_layer_sizes=(32, 96, 192) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 192), total=  40.0s
# [CV] hidden_layer_sizes=(32, 96, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 224), total=  40.2s
# [CV] hidden_layer_sizes=(32, 96, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 224), total= 1.1min
# [CV] hidden_layer_sizes=(32, 96, 224) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 224), total=  34.9s
# [CV] hidden_layer_sizes=(32, 96, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 256), total=  37.9s
# [CV] hidden_layer_sizes=(32, 96, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 256), total=  50.2s
# [CV] hidden_layer_sizes=(32, 96, 256) ................................
# [CV] ................. hidden_layer_sizes=(32, 96, 256), total=  39.3s
# [CV] hidden_layer_sizes=(32, 128, 32) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 32), total=  49.8s
# [CV] hidden_layer_sizes=(32, 128, 32) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 32), total=  35.4s
# [CV] hidden_layer_sizes=(32, 128, 32) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 32), total=  39.8s
# [CV] hidden_layer_sizes=(32, 128, 64) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 64), total=  42.6s
# [CV] hidden_layer_sizes=(32, 128, 64) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 64), total=  41.7s
# [CV] hidden_layer_sizes=(32, 128, 64) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 64), total=  36.1s
# [CV] hidden_layer_sizes=(32, 128, 96) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 96), total=  33.3s
# [CV] hidden_layer_sizes=(32, 128, 96) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 96), total=  34.5s
# [CV] hidden_layer_sizes=(32, 128, 96) ................................
# [CV] ................. hidden_layer_sizes=(32, 128, 96), total=  33.2s
# [CV] hidden_layer_sizes=(32, 128, 128) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 128), total=  34.4s
# [CV] hidden_layer_sizes=(32, 128, 128) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 128), total=  39.0s
# [CV] hidden_layer_sizes=(32, 128, 128) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 128), total=  32.4s
# [CV] hidden_layer_sizes=(32, 128, 160) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 160), total=  46.7s
# [CV] hidden_layer_sizes=(32, 128, 160) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 160), total=  44.1s
# [CV] hidden_layer_sizes=(32, 128, 160) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 160), total=  47.8s
# [CV] hidden_layer_sizes=(32, 128, 192) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 192), total=  51.5s
# [CV] hidden_layer_sizes=(32, 128, 192) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 192), total=  55.3s
# [CV] hidden_layer_sizes=(32, 128, 192) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 192), total=  52.6s
# [CV] hidden_layer_sizes=(32, 128, 224) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 224), total=  57.1s
# [CV] hidden_layer_sizes=(32, 128, 224) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 224), total= 1.0min
# [CV] hidden_layer_sizes=(32, 128, 224) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 224), total=  42.1s
# [CV] hidden_layer_sizes=(32, 128, 256) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 256), total=  36.5s
# [CV] hidden_layer_sizes=(32, 128, 256) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 256), total=  38.6s
# [CV] hidden_layer_sizes=(32, 128, 256) ...............................
# [CV] ................ hidden_layer_sizes=(32, 128, 256), total=  53.2s
# [CV] hidden_layer_sizes=(32, 160, 32) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 32), total=  48.6s
# [CV] hidden_layer_sizes=(32, 160, 32) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 32), total=  27.0s
# [CV] hidden_layer_sizes=(32, 160, 32) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 32), total=  37.6s
# [CV] hidden_layer_sizes=(32, 160, 64) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 64), total=  48.9s
# [CV] hidden_layer_sizes=(32, 160, 64) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 64), total=  28.5s
# [CV] hidden_layer_sizes=(32, 160, 64) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 64), total=  34.4s
# [CV] hidden_layer_sizes=(32, 160, 96) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 96), total=  34.4s
# [CV] hidden_layer_sizes=(32, 160, 96) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 96), total=  41.8s
# [CV] hidden_layer_sizes=(32, 160, 96) ................................
# [CV] ................. hidden_layer_sizes=(32, 160, 96), total=  33.3s
# [CV] hidden_layer_sizes=(32, 160, 128) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 128), total=  48.3s
# [CV] hidden_layer_sizes=(32, 160, 128) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 128), total=  33.0s
# [CV] hidden_layer_sizes=(32, 160, 128) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 128), total=  30.5s
# [CV] hidden_layer_sizes=(32, 160, 160) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 160), total=  44.0s
# [CV] hidden_layer_sizes=(32, 160, 160) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 160), total=  43.9s
# [CV] hidden_layer_sizes=(32, 160, 160) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 160), total=  45.1s
# [CV] hidden_layer_sizes=(32, 160, 192) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 192), total=  57.7s
# [CV] hidden_layer_sizes=(32, 160, 192) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 192), total=  45.6s
# [CV] hidden_layer_sizes=(32, 160, 192) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 192), total=  54.6s
# [CV] hidden_layer_sizes=(32, 160, 224) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 224), total=  53.0s
# [CV] hidden_layer_sizes=(32, 160, 224) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 224), total=  47.6s
# [CV] hidden_layer_sizes=(32, 160, 224) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 224), total=  36.5s
# [CV] hidden_layer_sizes=(32, 160, 256) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 256), total=  44.2s
# [CV] hidden_layer_sizes=(32, 160, 256) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 256), total=  51.9s
# [CV] hidden_layer_sizes=(32, 160, 256) ...............................
# [CV] ................ hidden_layer_sizes=(32, 160, 256), total=  49.6s
# ...
# [CV] n_estimators=20 .................................................
# [CV] .................................. n_estimators=20, total=  15.0s
# [CV] n_estimators=30 .................................................
# [CV] .................................. n_estimators=30, total=  22.4s
# [CV] n_estimators=30 .................................................
# [CV] .................................. n_estimators=30, total=  22.2s
# [CV] n_estimators=30 .................................................
# [CV] .................................. n_estimators=30, total=  22.3s
# [CV] n_estimators=40 .................................................
# [CV] .................................. n_estimators=40, total=  29.5s
# [CV] n_estimators=40 .................................................
# [CV] .................................. n_estimators=40, total=  29.4s
# [CV] n_estimators=40 .................................................
# [CV] .................................. n_estimators=40, total=  29.9s
# [CV] n_estimators=50 .................................................
# [CV] .................................. n_estimators=50, total=  37.4s
# [CV] n_estimators=50 .................................................
# [CV] .................................. n_estimators=50, total=  37.3s
# [CV] n_estimators=50 .................................................
# [CV] .................................. n_estimators=50, total=  37.6s
# [CV] n_estimators=60 .................................................
# [CV] .................................. n_estimators=60, total=  45.3s
# [CV] n_estimators=60 .................................................
# [CV] .................................. n_estimators=60, total=  44.6s
# [CV] n_estimators=60 .................................................
# [CV] .................................. n_estimators=60, total=  46.0s
# [CV] n_estimators=70 .................................................
# [CV] .................................. n_estimators=70, total=  52.1s
# [CV] n_estimators=70 .................................................
# [CV] .................................. n_estimators=70, total=  52.3s
# [CV] n_estimators=70 .................................................
# [CV] .................................. n_estimators=70, total=  52.7s
# [CV] n_estimators=80 .................................................
# [CV] .................................. n_estimators=80, total=  58.9s
# [CV] n_estimators=80 .................................................
# [CV] .................................. n_estimators=80, total=  59.9s
# [CV] n_estimators=80 .................................................
# [CV] .................................. n_estimators=80, total=  59.1s
# [CV] n_estimators=90 .................................................
# [CV] .................................. n_estimators=90, total= 1.1min
# [CV] n_estimators=90 .................................................
# [CV] .................................. n_estimators=90, total= 1.1min
# [CV] n_estimators=90 .................................................
# [CV] .................................. n_estimators=90, total= 1.1min
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total= 1.2min
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total= 1.2min
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total= 1.2min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 20.2min finished
# AdaBoostClassifier  : Best: 0.386232 using {'n_estimators': 60}
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [CV] C=0.1, kernel=linear ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................. C=0.1, kernel=linear, total= 1.9min
# [CV] C=0.1, kernel=linear ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.8min remaining:    0.0s
# [CV] ............................. C=0.1, kernel=linear, total= 1.9min
# [CV] C=0.1, kernel=linear ............................................
# [CV] ............................. C=0.1, kernel=linear, total= 1.9min
# [CV] C=0.1, kernel=poly ..............................................
# [CV] ............................... C=0.1, kernel=poly, total= 2.2min
# [CV] C=0.1, kernel=poly ..............................................
# [CV] ............................... C=0.1, kernel=poly, total= 2.1min
# [CV] C=0.1, kernel=poly ..............................................
# [CV] ............................... C=0.1, kernel=poly, total= 2.1min
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ................................ C=0.1, kernel=rbf, total= 2.2min
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ................................ C=0.1, kernel=rbf, total= 2.2min
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ................................ C=0.1, kernel=rbf, total= 2.2min
# [CV] C=0.1, kernel=sigmoid ...........................................
# [CV] ............................ C=0.1, kernel=sigmoid, total= 2.3min
# [CV] C=0.1, kernel=sigmoid ...........................................
# [CV] ............................ C=0.1, kernel=sigmoid, total= 2.3min
# [CV] C=0.1, kernel=sigmoid ...........................................
# [CV] ............................ C=0.1, kernel=sigmoid, total= 2.2min
# [CV] C=0.4, kernel=linear ............................................
# [CV] ............................. C=0.4, kernel=linear, total= 1.5min
# [CV] C=0.4, kernel=linear ............................................
# [CV] ............................. C=0.4, kernel=linear, total= 1.5min
# [CV] C=0.4, kernel=linear ............................................
# [CV] ............................. C=0.4, kernel=linear, total= 1.7min
# [CV] C=0.4, kernel=poly ..............................................
# [CV] ............................... C=0.4, kernel=poly, total= 2.2min
# [CV] C=0.4, kernel=poly ..............................................
# [CV] ............................... C=0.4, kernel=poly, total= 2.1min
# [CV] C=0.4, kernel=poly ..............................................
# [CV] ............................... C=0.4, kernel=poly, total= 2.1min
# [CV] C=0.4, kernel=rbf ...............................................
# [CV] ................................ C=0.4, kernel=rbf, total= 2.1min
# [CV] C=0.4, kernel=rbf ...............................................
# [CV] ................................ C=0.4, kernel=rbf, total= 2.1min
# [CV] C=0.4, kernel=rbf ...............................................
# [CV] ................................ C=0.4, kernel=rbf, total= 2.1min
# [CV] C=0.4, kernel=sigmoid ...........................................
# [CV] ............................ C=0.4, kernel=sigmoid, total= 2.1min
# [CV] C=0.4, kernel=sigmoid ...........................................
# [CV] ............................ C=0.4, kernel=sigmoid, total= 2.1min
# [CV] C=0.4, kernel=sigmoid ...........................................
# [CV] ............................ C=0.4, kernel=sigmoid, total= 2.1min
# [CV] C=0.7000000000000001, kernel=linear .............................
# [CV] .............. C=0.7000000000000001, kernel=linear, total= 1.4min
# [CV] C=0.7000000000000001, kernel=linear .............................
# [CV] .............. C=0.7000000000000001, kernel=linear, total= 1.4min
# [CV] C=0.7000000000000001, kernel=linear .............................
# [CV] .............. C=0.7000000000000001, kernel=linear, total= 1.5min
# [CV] C=0.7000000000000001, kernel=poly ...............................
# [CV] ................ C=0.7000000000000001, kernel=poly, total= 2.1min
# [CV] C=0.7000000000000001, kernel=poly ...............................
# [CV] ................ C=0.7000000000000001, kernel=poly, total= 2.1min
# [CV] C=0.7000000000000001, kernel=poly ...............................
# [CV] ................ C=0.7000000000000001, kernel=poly, total= 2.1min
# [CV] C=0.7000000000000001, kernel=rbf ................................
# [CV] ................. C=0.7000000000000001, kernel=rbf, total= 2.1min
# [CV] C=0.7000000000000001, kernel=rbf ................................
# [CV] ................. C=0.7000000000000001, kernel=rbf, total= 2.1min
# [CV] C=0.7000000000000001, kernel=rbf ................................
# [CV] ................. C=0.7000000000000001, kernel=rbf, total= 2.2min
# [CV] C=0.7000000000000001, kernel=sigmoid ............................
# [CV] ............. C=0.7000000000000001, kernel=sigmoid, total= 2.1min
# [CV] C=0.7000000000000001, kernel=sigmoid ............................
# [CV] ............. C=0.7000000000000001, kernel=sigmoid, total= 2.1min
# [CV] C=0.7000000000000001, kernel=sigmoid ............................
# [CV] ............. C=0.7000000000000001, kernel=sigmoid, total= 2.1min
# [CV] C=1.0000000000000002, kernel=linear .............................
# [CV] .............. C=1.0000000000000002, kernel=linear, total= 1.3min
# [CV] C=1.0000000000000002, kernel=linear .............................
# [CV] .............. C=1.0000000000000002, kernel=linear, total= 1.3min
# [CV] C=1.0000000000000002, kernel=linear .............................
# [CV] .............. C=1.0000000000000002, kernel=linear, total= 1.4min
# [CV] C=1.0000000000000002, kernel=poly ...............................
# [CV] ................ C=1.0000000000000002, kernel=poly, total= 2.1min
# [CV] C=1.0000000000000002, kernel=poly ...............................
# [CV] ................ C=1.0000000000000002, kernel=poly, total= 2.1min
# [CV] C=1.0000000000000002, kernel=poly ...............................
# [CV] ................ C=1.0000000000000002, kernel=poly, total= 2.1min
# [CV] C=1.0000000000000002, kernel=rbf ................................
# [CV] ................. C=1.0000000000000002, kernel=rbf, total= 2.1min
# [CV] C=1.0000000000000002, kernel=rbf ................................
# [CV] ................. C=1.0000000000000002, kernel=rbf, total= 2.1min
# [CV] C=1.0000000000000002, kernel=rbf ................................
# [CV] ................. C=1.0000000000000002, kernel=rbf, total= 2.2min
# [CV] C=1.0000000000000002, kernel=sigmoid ............................
# [CV] ............. C=1.0000000000000002, kernel=sigmoid, total= 2.1min
# [CV] C=1.0000000000000002, kernel=sigmoid ............................
# [CV] ............. C=1.0000000000000002, kernel=sigmoid, total= 2.1min
# [CV] C=1.0000000000000002, kernel=sigmoid ............................
# [CV] ............. C=1.0000000000000002, kernel=sigmoid, total= 2.1min
# [CV] C=1.3000000000000003, kernel=linear .............................
# [CV] .............. C=1.3000000000000003, kernel=linear, total= 1.3min
# [CV] C=1.3000000000000003, kernel=linear .............................
# [CV] .............. C=1.3000000000000003, kernel=linear, total= 1.3min
# [CV] C=1.3000000000000003, kernel=linear .............................
# [CV] .............. C=1.3000000000000003, kernel=linear, total= 1.4min
# [CV] C=1.3000000000000003, kernel=poly ...............................
# [CV] ................ C=1.3000000000000003, kernel=poly, total= 2.1min
# [CV] C=1.3000000000000003, kernel=poly ...............................
# [CV] ................ C=1.3000000000000003, kernel=poly, total= 2.1min
# [CV] C=1.3000000000000003, kernel=poly ...............................
# [CV] ................ C=1.3000000000000003, kernel=poly, total= 2.1min
# [CV] C=1.3000000000000003, kernel=rbf ................................
# [CV] ................. C=1.3000000000000003, kernel=rbf, total= 2.1min
# [CV] C=1.3000000000000003, kernel=rbf ................................
# [CV] ................. C=1.3000000000000003, kernel=rbf, total= 2.1min
# [CV] C=1.3000000000000003, kernel=rbf ................................
# [CV] ................. C=1.3000000000000003, kernel=rbf, total= 2.2min
# [CV] C=1.3000000000000003, kernel=sigmoid ............................
# [CV] ............. C=1.3000000000000003, kernel=sigmoid, total= 2.1min
# [CV] C=1.3000000000000003, kernel=sigmoid ............................
# [CV] ............. C=1.3000000000000003, kernel=sigmoid, total= 2.1min
# [CV] C=1.3000000000000003, kernel=sigmoid ............................
# [CV] ............. C=1.3000000000000003, kernel=sigmoid, total= 2.1min
# [CV] C=1.6000000000000003, kernel=linear .............................
# [CV] .............. C=1.6000000000000003, kernel=linear, total= 1.2min
# [CV] C=1.6000000000000003, kernel=linear .............................
# [CV] .............. C=1.6000000000000003, kernel=linear, total= 1.3min
# [CV] C=1.6000000000000003, kernel=linear .............................
# [CV] .............. C=1.6000000000000003, kernel=linear, total= 1.3min
# [CV] C=1.6000000000000003, kernel=poly ...............................
# [CV] ................ C=1.6000000000000003, kernel=poly, total= 2.1min
# [CV] C=1.6000000000000003, kernel=poly ...............................
# [CV] ................ C=1.6000000000000003, kernel=poly, total= 2.1min
# [CV] C=1.6000000000000003, kernel=poly ...............................
# [CV] ................ C=1.6000000000000003, kernel=poly, total= 2.1min
# [CV] C=1.6000000000000003, kernel=rbf ................................
# [CV] ................. C=1.6000000000000003, kernel=rbf, total= 2.1min
# [CV] C=1.6000000000000003, kernel=rbf ................................
# [CV] ................. C=1.6000000000000003, kernel=rbf, total= 2.1min
# [CV] C=1.6000000000000003, kernel=rbf ................................
# [CV] ................. C=1.6000000000000003, kernel=rbf, total= 2.1min
# [CV] C=1.6000000000000003, kernel=sigmoid ............................
# [CV] ............. C=1.6000000000000003, kernel=sigmoid, total= 2.1min
# [CV] C=1.6000000000000003, kernel=sigmoid ............................
# [CV] ............. C=1.6000000000000003, kernel=sigmoid, total= 2.1min
# [CV] C=1.6000000000000003, kernel=sigmoid ............................
# [CV] ............. C=1.6000000000000003, kernel=sigmoid, total= 2.1min
# [CV] C=1.9000000000000004, kernel=linear .............................
# [CV] .............. C=1.9000000000000004, kernel=linear, total= 1.2min
# [CV] C=1.9000000000000004, kernel=linear .............................
# [CV] .............. C=1.9000000000000004, kernel=linear, total= 1.2min
# [CV] C=1.9000000000000004, kernel=linear .............................
# [CV] .............. C=1.9000000000000004, kernel=linear, total= 1.3min
# [CV] C=1.9000000000000004, kernel=poly ...............................
# [CV] ................ C=1.9000000000000004, kernel=poly, total= 2.0min
# [CV] C=1.9000000000000004, kernel=poly ...............................
# [CV] ................ C=1.9000000000000004, kernel=poly, total= 2.0min
# [CV] C=1.9000000000000004, kernel=poly ...............................
# [CV] ................ C=1.9000000000000004, kernel=poly, total= 2.0min
# [CV] C=1.9000000000000004, kernel=rbf ................................
# [CV] ................. C=1.9000000000000004, kernel=rbf, total= 2.1min
# [CV] C=1.9000000000000004, kernel=rbf ................................
# [CV] ................. C=1.9000000000000004, kernel=rbf, total= 2.1min
# [CV] C=1.9000000000000004, kernel=rbf ................................
# [CV] ................. C=1.9000000000000004, kernel=rbf, total= 2.1min
# [CV] C=1.9000000000000004, kernel=sigmoid ............................
# [CV] ............. C=1.9000000000000004, kernel=sigmoid, total= 2.1min
# [CV] C=1.9000000000000004, kernel=sigmoid ............................
# [CV] ............. C=1.9000000000000004, kernel=sigmoid, total= 2.1min
# [CV] C=1.9000000000000004, kernel=sigmoid ............................
# [CV] ............. C=1.9000000000000004, kernel=sigmoid, total= 2.1min
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed: 244.0min finished
# SVC  : Best: 0.445667 using {'C': 0.4, 'kernel': 'linear'}

# %%
classifier_dic
# Out:
# {'MLPClassifier': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#         beta_2=0.999, early_stopping=True, epsilon=1e-08,
#         hidden_layer_sizes=(100,), learning_rate='constant',
#         learning_rate_init=0.001, max_iter=500, momentum=0.9,
#         n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#         random_state=None, shuffle=True, solver='adam', tol=0.0001,
#         validation_fraction=0.1, verbose=False, warm_start=False),
#  'LogisticRegression': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='auto',
#            n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#            tol=0.0001, verbose=0, warm_start=False),
#  'AdaBoostClassifier': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#            learning_rate=1.0, n_estimators=50, random_state=None),
#  'SVC': SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#    max_iter=-1, probability=False, random_state=None, shrinking=True,
#    tol=0.001, verbose=False)}

# %%
for key in grid_result:
    classifier_dic[key] = grid_result[key].best_estimator_

# %%
classifier_dic
# Out:
# {'MLPClassifier': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#         beta_2=0.999, early_stopping=True, epsilon=1e-08,
#         hidden_layer_sizes=(224, 192, 160), learning_rate='constant',
#         learning_rate_init=0.001, max_iter=500, momentum=0.9,
#         n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#         random_state=None, shuffle=True, solver='adam', tol=0.0001,
#         validation_fraction=0.1, verbose=False, warm_start=False),
#  'LogisticRegression': LogisticRegression(C=0.4, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='auto',
#            n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#            tol=0.0001, verbose=0, warm_start=False),
#  'AdaBoostClassifier': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#            learning_rate=1.0, n_estimators=60, random_state=None),
#  'SVC': SVC(C=0.4, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#    max_iter=-1, probability=False, random_state=None, shrinking=True,
#    tol=0.001, verbose=False)}

# %% [markdown]
# #### Cross-validation

# %%
scores = cross_validation(classifier_dic, x, y)
# Out:
# MLPClassifier  scores:  {'fit_time': array([51.44965816, 56.59893203, 46.19132113]), 'score_time': array([0.12717366, 0.10879779, 0.17913914]), 'test_precision_weighted': array([0.42537576, 0.43951351, 0.47879742]), 'train_precision_weighted': array([0.78676397, 0.79959736, 0.68934307]), 'test_recall_weighted': array([0.4140414 , 0.43667467, 0.45539201]), 'train_recall_weighted': array([0.78306561, 0.79930952, 0.68747187]), 'test_f1_weighted': array([0.38261431, 0.43735707, 0.46259672]), 'train_f1_weighted': array([0.7803419 , 0.7984398 , 0.68738088])}
#
# LogisticRegression  scores:  {'fit_time': array([3.87779951, 4.54455662, 4.33399916]), 'score_time': array([0.02047086, 0.02287316, 0.01790047]), 'test_precision_weighted': array([0.42213601, 0.41271386, 0.46889787]), 'train_precision_weighted': array([0.6655802 , 0.65958325, 0.63241605]), 'test_recall_weighted': array([0.40624062, 0.43187275, 0.48182637]), 'train_recall_weighted': array([0.66791773, 0.66196337, 0.63630908]), 'test_f1_weighted': array([0.37302963, 0.41897754, 0.46768893]), 'train_f1_weighted': array([0.66359472, 0.65783632, 0.62862139])}
#
# AdaBoostClassifier  scores:  {'fit_time': array([43.72604537, 43.8225615 , 43.71401286]), 'score_time': array([0.33397961, 0.32562804, 0.33024478]), 'test_precision_weighted': array([0.35773917, 0.36788646, 0.43924167]), 'train_precision_weighted': array([0.49484904, 0.4761225 , 0.46259861]), 'test_recall_weighted': array([0.3480348 , 0.36944778, 0.44127366]), 'train_recall_weighted': array([0.4981234 , 0.48348844, 0.46901725]), 'test_f1_weighted': array([0.32238771, 0.36674053, 0.43893225]), 'train_f1_weighted': array([0.49600148, 0.47863499, 0.46512384])}
#
# SVC  scores:  {'fit_time': array([62.47271395, 62.39777756, 66.00581861]), 'score_time': array([79.528368  , 78.99606848, 81.36965609]), 'test_precision_weighted': array([0.43527019, 0.43572519, 0.48746164]), 'train_precision_weighted': array([0.69119498, 0.68229833, 0.65623359]), 'test_recall_weighted': array([0.41164116, 0.43907563, 0.48633223]), 'train_recall_weighted': array([0.69148776, 0.68132693, 0.65686422]), 'test_f1_weighted': array([0.38592526, 0.43728542, 0.48284091]), 'train_f1_weighted': array([0.69123975, 0.68055738, 0.65536896])}

# %% [markdown]
# ## Sentiment Words

# %%
from scipy.sparse import hstack

# %%
positive_words = pandas.read_csv('input/positive-words.txt', delimiter = "\t", header=None, 
                                 encoding='utf-8', names=["positive_words"])
negative_words = pandas.read_csv('input/negative-words.txt', delimiter = "\t", header=None, 
                                 encoding='utf-8', names=["negative_words"])

# %%
positive_words = process_dataframe(positive_words, ["positive_words"], ["positive_word_token"])
negative_words = process_dataframe(negative_words, ["negative_words"], ["negative_word_token"])

# %%
positive_words.drop_duplicates(subset ="positive_word_token", keep = False, inplace = True)
negative_words.drop_duplicates(subset ="negative_word_token", keep = False, inplace = True)

# %%
positive_word_vector = vectorize_words(training, "word_token", positive_words["positive_word_token"].values )
negative_word_vector = vectorize_words(training, "word_token", negative_words["negative_word_token"].values )

# %%
x_train_naive = hstack((positive_word_vector, negative_word_vector))

# %%
svd, x_train = svd_words(x_train_naive)

# %% [markdown]
# #### Cross-validation

# %%
scores = cross_validation(classifier_dic, x_train, y)
# Out:
# MLPClassifier  scores:  {'fit_time': array([46.51154065, 49.24570537, 54.11338973]), 'score_time': array([0.29101944, 0.17219973, 0.10764194]), 'test_precision_weighted': array([0.37512241, 0.35848457, 0.39421927]), 'train_precision_weighted': array([0.50620237, 0.48660251, 0.57099751]), 'test_recall_weighted': array([0.37233723, 0.3622449 , 0.39681586]), 'train_recall_weighted': array([0.49947455, 0.48649054, 0.55828957]), 'test_f1_weighted': array([0.36494665, 0.34836838, 0.38622813]), 'train_f1_weighted': array([0.49740406, 0.47707109, 0.54723746])}
#
# LogisticRegression  scores:  {'fit_time': array([4.34997749, 4.56386471, 4.57805753]), 'score_time': array([0.02422929, 0.01689863, 0.01790404]), 'test_precision_weighted': array([0.34012933, 0.37132648, 0.38715564]), 'train_precision_weighted': array([0.50874328, 0.49847636, 0.49308033]), 'test_recall_weighted': array([0.34983498, 0.37635054, 0.39591469]), 'train_recall_weighted': array([0.50923285, 0.49759832, 0.49407352]), 'test_f1_weighted': array([0.33727917, 0.36974814, 0.38526426]), 'train_f1_weighted': array([0.50596924, 0.49125995, 0.48583477])}
#
# AdaBoostClassifier  scores:  {'fit_time': array([40.24427819, 39.1104846 , 39.21837234]), 'score_time': array([0.31378841, 0.36378765, 0.35976696]), 'test_precision_weighted': array([0.32513143, 0.32371942, 0.34923219]), 'train_precision_weighted': array([0.41175736, 0.39715952, 0.38353341]), 'test_recall_weighted': array([0.33243324, 0.32773109, 0.3544608 ]), 'train_recall_weighted': array([0.41645399, 0.40213149, 0.38739685]), 'test_f1_weighted': array([0.32068998, 0.32160567, 0.34931339]), 'train_f1_weighted': array([0.41109098, 0.39555558, 0.38383454])}
#
# SVC  scores:  {'fit_time': array([73.66225696, 69.83859277, 71.60508585]), 'score_time': array([79.80837035, 80.94639635, 81.76034236]), 'test_precision_weighted': array([0.34113823, 0.36750117, 0.37667851]), 'train_precision_weighted': array([0.52148401, 0.51355807, 0.50114776]), 'test_recall_weighted': array([0.34713471, 0.37034814, 0.38329829]), 'train_recall_weighted': array([0.52079267, 0.50945662, 0.49782446]), 'test_f1_weighted': array([0.33668994, 0.3637447 , 0.37401499]), 'train_f1_weighted': array([0.51930602, 0.50433108, 0.49126717])}

# %% [markdown]
# ## Testing

# %%
from sklearn.metrics import classification_report

# %%
testing = pandas.read_csv('input/test.txt', delimiter = "\t", header=None)
testing.columns = columns

# %%
testing = process_dataframe(testing, ["review_text"], ["word_token"])

# %%
testing_positive_word_dataframe = vectorize_words(testing, "word_token", positive_words["positive_word_token"].values )
testing_negative_word_dataframe = vectorize_words(testing, "word_token", negative_words["negative_word_token"].values )

# %%
x_true_naive = hstack((testing_positive_word_dataframe, testing_negative_word_dataframe))

# %%
x_true = svd.transform(x_true_naive)

# %%
y_true = testing["score"]
y_true = np.ravel(y_true)

# %%
for key, classifier in classifier_dic.items():
    classifier.fit(x_train, y)
    y_pred = classifier.predict(x_true)
    print(key, " : \n", classification_report(y_true, y_pred))
# Out:
# MLPClassifier  :
#                precision    recall  f1-score   support
#
#          1.0       0.43      0.58      0.49       200
#          2.0       0.30      0.13      0.18       200
#          3.0       0.27      0.39      0.32       200
#          4.0       0.33      0.17      0.23       200
#          5.0       0.39      0.50      0.44       200
#
#    micro avg       0.35      0.35      0.35      1000
#    macro avg       0.34      0.35      0.33      1000
# weighted avg       0.34      0.35      0.33      1000
#
# LogisticRegression  :
#                precision    recall  f1-score   support
#
#          1.0       0.46      0.52      0.48       200
#          2.0       0.33      0.29      0.31       200
#          3.0       0.27      0.28      0.28       200
#          4.0       0.32      0.25      0.28       200
#          5.0       0.42      0.49      0.46       200
#
#    micro avg       0.37      0.37      0.37      1000
#    macro avg       0.36      0.37      0.36      1000
# weighted avg       0.36      0.37      0.36      1000
#
# AdaBoostClassifier  :
#                precision    recall  f1-score   support
#
#          1.0       0.43      0.47      0.45       200
#          2.0       0.29      0.29      0.29       200
#          3.0       0.25      0.18      0.21       200
#          4.0       0.32      0.32      0.32       200
#          5.0       0.39      0.46      0.42       200
#
#    micro avg       0.34      0.34      0.34      1000
#    macro avg       0.34      0.34      0.34      1000
# weighted avg       0.34      0.34      0.34      1000
#
# SVC  :
#                precision    recall  f1-score   support
#
#          1.0       0.45      0.46      0.45       200
#          2.0       0.31      0.28      0.30       200
#          3.0       0.27      0.28      0.28       200
#          4.0       0.31      0.24      0.27       200
#          5.0       0.42      0.51      0.46       200
#
#    micro avg       0.36      0.36      0.36      1000
#    macro avg       0.35      0.36      0.35      1000
# weighted avg       0.35      0.36      0.35      1000

# %% [markdown]
# ## Special Section for Naive Bayes

# %%
# MultinomialNB does not work with PCA, SVD or any other matrix factorization
# Non-Negative Matrix Factorization (NMF) works but gives 0.04% accuracy
multinomialNB = MultinomialNB()

# %%
MultinomialNB = {"MultinomialNB": multinomialNB}

# %% [markdown]
# ### For base case

# %%
scores = cross_validation(MultinomialNB, x_naive, y)
# Out:
# MultinomialNB  scores:  {'fit_time': array([0.01318097, 0.01035047, 0.01041579]), 'score_time': array([0.0080874 , 0.00922632, 0.0090096 ]), 'test_precision_weighted': array([0.39931921, 0.36904878, 0.48401381]), 'train_precision_weighted': array([0.77569485, 0.76233826, 0.75907781]), 'test_recall_weighted': array([0.35283528, 0.35204082, 0.44127366]), 'train_recall_weighted': array([0.7710554 , 0.74707295, 0.75363841]), 'test_f1_weighted': array([0.32224638, 0.35493944, 0.45020898]), 'train_f1_weighted': array([0.77124942, 0.7485308 , 0.75393127])}

# %% [markdown]
# ### including sentiment

# %%
scores = cross_validation(MultinomialNB, x_train_naive, y)
# Out:
# MultinomialNB  scores:  {'fit_time': array([0.00374031, 0.00329423, 0.0032599 ]), 'score_time': array([0.00464392, 0.00451684, 0.00445366]), 'test_precision_weighted': array([0.34205694, 0.35014896, 0.37046502]), 'train_precision_weighted': array([0.53031574, 0.5197462 , 0.51206761]), 'test_recall_weighted': array([0.34533453, 0.35744298, 0.37999399]), 'train_recall_weighted': array([0.52950008, 0.51921345, 0.51237809]), 'test_f1_weighted': array([0.33442996, 0.35164079, 0.37290812]), 'train_f1_weighted': array([0.52654192, 0.51552732, 0.507029  ])}

# %%
multinomialNB.fit(x_train_naive, y)
y_pred = multinomialNB.predict(x_true_naive)
print("MultinomialNB : \n", classification_report(y_true, y_pred))
# Out:
# MultinomialNB :
#                precision    recall  f1-score   support
#
#          1.0       0.41      0.52      0.45       200
#          2.0       0.35      0.34      0.34       200
#          3.0       0.26      0.27      0.26       200
#          4.0       0.32      0.30      0.31       200
#          5.0       0.40      0.32      0.36       200
#
#    micro avg       0.35      0.35      0.35      1000
#    macro avg       0.35      0.35      0.35      1000
# weighted avg       0.35      0.35      0.35      1000

# %% [markdown]
# ### finding the tough

# %%
classifier = classifier_dic["AdaBoostClassifier"]
classifier.fit(x_train, y)
for i in range(1,6):
    
    df = testing.loc[testing['score'] == i]
    
    testing_positive_word_dataframe = vectorize_words(df, "word_token", positive_words["positive_word_token"].values )
    testing_negative_word_dataframe = vectorize_words(df, "word_token", negative_words["negative_word_token"].values )
    
    x_true_naive = hstack((testing_positive_word_dataframe, testing_negative_word_dataframe)) 
    x_true = svd.transform(x_true_naive)
    
    y_true = df["score"]
    y_true = np.ravel(y_true)
    
    y_pred = classifier.predict(x_true)
    print("Score = ", i, " : \n", classification_report(y_true, y_pred))
# Out:
# /home/mhssain9/virtualenv/ML_Project/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/mhssain9/virtualenv/ML_Project/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/mhssain9/virtualenv/ML_Project/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Score =  1  :
#                precision    recall  f1-score   support
#
#          1.0       1.00      0.43      0.61       200
#          2.0       0.00      0.00      0.00         0
#          3.0       0.00      0.00      0.00         0
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#    micro avg       0.43      0.43      0.43       200
#    macro avg       0.20      0.09      0.12       200
# weighted avg       1.00      0.43      0.61       200
#
# Score =  2  :
#                precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00         0
#          2.0       1.00      0.29      0.45       200
#          3.0       0.00      0.00      0.00         0
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#    micro avg       0.29      0.29      0.29       200
#    macro avg       0.20      0.06      0.09       200
# weighted avg       1.00      0.29      0.45       200
#
# Score =  3  :
#                precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00         0
#          2.0       0.00      0.00      0.00         0
#          3.0       1.00      0.15      0.27       200
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#    micro avg       0.15      0.15      0.15       200
#    macro avg       0.20      0.03      0.05       200
# weighted avg       1.00      0.15      0.27       200
#
# Score =  4  :
#                precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00         0
#          2.0       0.00      0.00      0.00         0
#          3.0       0.00      0.00      0.00         0
#          4.0       1.00      0.33      0.49       200
#          5.0       0.00      0.00      0.00         0
#
#    micro avg       0.33      0.33      0.33       200
#    macro avg       0.20      0.07      0.10       200
# weighted avg       1.00      0.33      0.49       200
#
# Score =  5  :
#                precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00         0
#          2.0       0.00      0.00      0.00         0
#          3.0       0.00      0.00      0.00         0
#          4.0       0.00      0.00      0.00         0
#          5.0       1.00      0.46      0.63       200
#
#    micro avg       0.46      0.46      0.46       200
#    macro avg       0.20      0.09      0.13       200
# weighted avg       1.00      0.46      0.63       200
# /home/mhssain9/virtualenv/ML_Project/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/mhssain9/virtualenv/ML_Project/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
